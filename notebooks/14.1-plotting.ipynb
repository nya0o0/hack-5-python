# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.datasets import load_iris
from sklearn.linear_model import LinearRegression

# %%
iris = load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# ...

# %%
# Define a variable for the feature we wish to plot
feature = "sepal length (cm)"
# Group the data in the dataframe by species ID
gb = iris_df.groupby("species")
# Iterate through the groupby object
for sp, dat in gb:
    # For each species, plot the data for the given feature as a histogram
    plt.hist(dat[feature], label=sp)
# Out:
# /tmp/ipykernel_2095/710689226.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = iris_df.groupby("species")

# %%
feature = "sepal length (cm)"
gb = iris_df.groupby("species")
for sp, dat in gb:
    plt.hist(dat[feature], label=sp, alpha=0.3)
plt.legend()
# Out:
# /tmp/ipykernel_2095/2049643895.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = iris_df.groupby("species")

# %%
feature = "sepal length (cm)"
gb = iris_df.groupby("species")
# Create a dictionary mapping species IDs to color names, which we will access inside the for loop
cdict = {'setosa':'cornflowerblue',
         'versicolor':'salmon',
         'virginica':'goldenrod'}
for sp, dat in gb:
    plt.hist(dat[feature], label=sp, alpha=0.5, color=cdict[sp])
# Out:
# /tmp/ipykernel_2095/744273426.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = iris_df.groupby("species")

# %%
feature = "sepal length (cm)"
gb = iris_df.groupby("species")
cdict = {'setosa':'cornflowerblue',
         'versicolor':'salmon',
         'virginica':'goldenrod'}
for sp, dat in gb:
    plt.hist(dat[feature], label=sp, alpha=0.5, color=cdict[sp])
plt.legend()
# Out:
# /tmp/ipykernel_2095/475594243.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = iris_df.groupby("species")

# %%
feature = "sepal length (cm)"
gb = iris_df.groupby("species")
cdict = {'setosa':'cornflowerblue',
         'versicolor':'salmon',
         'virginica':'goldenrod'}
for sp, dat in gb:
    plt.hist(dat[feature], label=sp, alpha=0.5, color=cdict[sp])

plt.title(f'Histogram of {feature} by Species')
plt.ylabel('Count')
plt.xlabel(feature)
# Out:
# /tmp/ipykernel_2095/3702659517.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = iris_df.groupby("species")
# Text(0.5, 0, 'sepal length (cm)')

# %%
feature = "sepal length (cm)"
gb = iris_df.groupby("species")
cdict = {'setosa':'cornflowerblue',
         'versicolor':'salmon',
         'virginica':'goldenrod'}
for sp, dat in gb:
    plt.hist(dat[feature], label=sp, alpha=0.5, color=cdict[sp])

plt.title(f'Histogram of {feature} by Species')
plt.ylabel('Count')
plt.xlabel(feature)
plt.savefig('sepal_length.png')
# Out:
# /tmp/ipykernel_2095/2008551865.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = iris_df.groupby("species")

# %%
plt.gcf().canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format',
#  'webp': 'WebP Image Format'}

# %% [markdown]
# ### Challenge: Visualize another column of data

# %%
feature = "petal length (cm)"
gb = iris_df.groupby("species")
cdict = {'setosa':'mediumseagreen',
         'versicolor':'lightseagreen',
         'virginica':'deepskyblue'}
for sp, dat in gb:
    plt.hist(dat[feature], label=sp, alpha=0.5, color=cdict[sp])

plt.title(f'Histogram of {feature} by Species')
plt.ylabel('Count')
plt.xlabel(feature)
plt.legend()
plt.savefig('petal_length.png')
# Out:
# /tmp/ipykernel_2095/4280845486.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = iris_df.groupby("species")

# %% [markdown]
# ### 2D

# %%
print(iris_df.columns)
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'species'],
#       dtype='object')

# %%
gb = iris_df.groupby("species")
x_feature = "sepal length (cm)"
y_feature = "sepal width (cm)"
for sp, dat in gb:
    plt.scatter(dat[x_feature], dat[y_feature], label=sp)
plt.legend()
# Out:
# /tmp/ipykernel_2095/3954536706.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = iris_df.groupby("species")

# %%
x_feature = "sepal length (cm)"
y_feature = "sepal width (cm)"

gb = iris_df.groupby("species")
cdict = {'setosa':'cornflowerblue',
         'versicolor':'salmon',
         'virginica':'goldenrod'}
for sp, dat in gb:
    plt.scatter(dat[x_feature], dat[y_feature], label=sp, alpha=0.75, color=cdict[sp])

plt.title(f'Histogram of {x_feature} and {y_feature} by Species')
plt.ylabel(y_feature)
plt.xlabel(x_feature)
plt.legend()
plt.savefig('sepal_length & sepal_width.png')
# Out:
# /tmp/ipykernel_2095/263948819.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = iris_df.groupby("species")

# %%
x_feature = "sepal length (cm)"
y_feature = "sepal width (cm)"

gb = iris_df.groupby("species")
cdict = {'setosa':'cornflowerblue',
         'versicolor':'salmon',
         'virginica':'goldenrod'}
for sp, dat in gb:
    plt.scatter(dat[x_feature], dat[y_feature], marker="*", label=sp, alpha=0.75, color=cdict[sp])

plt.title(f'Histogram of {x_feature} and {y_feature} by Species')
plt.ylabel(y_feature)
plt.xlabel(x_feature)
plt.legend()
plt.savefig('sepal_length & sepal_width.png')
# Out:
# /tmp/ipykernel_2095/1080118410.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = iris_df.groupby("species")

# %%
x_feature = "sepal length (cm)"
y_feature = "sepal width (cm)"
z_feature = "petal length (cm)"

gb = iris_df.groupby("species")
cdict = {'setosa':'cornflowerblue',
         'versicolor':'salmon',
         'virginica':'goldenrod'}
for sp, dat in gb:
    plt.scatter(dat[x_feature], dat[y_feature], s=dat[z_feature] * 20, marker="*", label=sp, alpha=0.75, color=cdict[sp])

plt.title(f'Scatter plot of {x_feature} vs {y_feature}, with marker size representing {z_feature}')
plt.xlabel(x_feature)
plt.ylabel(y_feature)
plt.legend()
plt.savefig('3D.png')
plt.show()
# Out:
# /tmp/ipykernel_2095/2660284771.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = iris_df.groupby("species")

# %%
import requests

# %%
url = "https://esapubs.org/archive/ecol/E084/093/Mammal_lifehistories_v2.txt"
response = requests.get(url)

# Save the file locally
with open("Mammal_lifehistories_v2.txt", "wb") as file:
    file.write(response.content)

# %%
# Load the dataset
df = pd.read_csv("Mammal_lifehistories_v2.txt", sep="\t", na_values=['-999', '-999.00'])

# Display basic info
print(df.head())
print(df.info())
# Out:
#           order          family        Genus        species   mass(g)  \
# 0  Artiodactyla  Antilocapridae  Antilocapra      americana   45375.0
# 1  Artiodactyla         Bovidae        Addax  nasomaculatus  182375.0
# 2  Artiodactyla         Bovidae    Aepyceros       melampus   41480.0
# 3  Artiodactyla         Bovidae   Alcelaphus     buselaphus  150000.0
# 4  Artiodactyla         Bovidae   Ammodorcas        clarkei   28500.0
#
#    gestation(mo)  newborn(g)  weaning(mo)  wean mass(g)  AFR(mo)  \
# 0           8.13     3246.36         3.00        8900.0    13.53
# 1           9.39     5480.00         6.50           NaN    27.27
# 2           6.35     5093.00         5.63       15900.0    16.66
# 3           7.90    10166.67         6.50           NaN    23.02
# 4           6.80         NaN          NaN           NaN      NaN
#
#    max. life(mo)  litter size  litters/year              refs
# 0          142.0         1.85          1.00  1,2,6,9,23,26,27
# ...

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df["mass(g)"], df["newborn(g)"], alpha=0.75, color = "cornflowerblue")
plt.xlabel("Adult Mass (g)")
plt.ylabel("Newborn Mass (g)")
plt.title("Adult Mass vs. Newborn Mass")
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(np.log10(df["mass(g)"]), np.log10(df["newborn(g)"]), alpha=0.5)
plt.xlabel("log10(Adult Mass) (g)")
plt.ylabel("log10(Newborn Mass) (g)")
plt.title("Log-Transformed Adult Mass vs. Newborn Mass")
plt.grid(True, linestyle="--", linewidth=0.5)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(np.log10(df["mass(g)"]),df["litter size"], alpha=0.5)
plt.xlabel("log10(Adult Mass (g))")
plt.ylabel("Litter Size")
plt.title("Adult Mass vs. Litter Size")
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df["mass(g)"], np.log10(df["litter size"]), alpha=0.5)
plt.xlabel("Adult Mass (g)")
plt.ylabel("log10(Litter Size)")
plt.title("Adult Mass vs. Litter Size")
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(np.log10(df["mass(g)"]), np.log10(df["litter size"]), alpha=0.5)
plt.xlabel("log10(Adult Mass (g))")
plt.ylabel("log10(Litter Size)")
plt.title("Adult Mass vs. Litter Size")
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df["mass(g)"], df["litter size"], alpha=0.5)
plt.xlabel("Adult Mass (g)")
plt.ylabel("Litter Size")
plt.title("Adult Mass vs. Litter Size")
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.show()

# %% [markdown]
# Apply a log scale to adult mass and litter size does not need log transformation.
